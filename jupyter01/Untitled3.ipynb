# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
img=Image.open('/sdcard/Download/09-22-07-l_hires.jpg')
print(img.size)
plt.figure('Image')
plt.imshow(img)
plt.title('image')
plt.axis('off')
plt.show()
im=np.array(img)/255.0
print(len(im),im.shape,np.max(im),im.dtype)
# Out:
# (1084, 2318)
# 2318 (2318, 1084, 3) 1.0 float64
